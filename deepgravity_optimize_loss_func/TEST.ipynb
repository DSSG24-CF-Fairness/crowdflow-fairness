# %%
import pandas as pd
import os 
demographics = pd.read_csv(r"C:\Users\fy916\Documents\Projects\crowdflow-fairness\deepgravity_optimize_loss_func\data\new_york0\demographics.csv")

# %%
demographics
# Out:
#      STATE        geoid  LOCATION     AREA_SQMI     svi
# 0       NY  36047000700  New York  7.271535e-12  0.2345
# 1       NY  36047000900  New York  6.724112e-12  0.1721
# 2       NY  36047001100  New York  6.931583e-12  0.1008
# 3       NY  36047001300  New York  1.206025e-11  0.3723
# 4       NY  36047002000  New York  6.336278e-12  0.9327
# ...    ...          ...       ...           ...     ...
# 5406    NY  36081027900  New York  7.293553e-12  0.8686
# 5407    NY  36081028000  New York  6.803193e-12  0.5275
# 5408    NY  36081028100  New York  7.181894e-12  0.6718
# 5409    NY  36081028200  New York  7.505020e-12  0.5155
# 5410    NY  36081028400  New York  1.766270e-11  0.5376
#
# [5411 rows x 5 columns]

# %%
# create geoid -> svi mapping
geoid_to_svi = demographics.set_index('geoid')['svi'].to_dict()
geoid_to_svi
# Out:
# {36047000700: 0.2345,
#  36047000900: 0.1721,
#  36047001100: 0.1008,
#  36047001300: 0.3723,
#  36047002000: 0.9327,
#  36047002100: 0.1843,
#  36047002200: 0.9629,
#  36047002901: 0.9776,
#  36047003400: 0.6191,
#  36047003700: 0.3442,
#  36047003900: 0.4117,
#  36005014100: 0.9616,
#  36005033000: 0.9179,
#  36005021100: 0.9859,
#  36005004600: 0.9992,
#  36005005902: 0.9182,
#  36005028100: 0.6996,
#  36005022701: 0.9994,
#  36005031600: 0.6528,
#  36005019500: 0.985,
#  36005028600: 0.3255,
#  36005016400: 0.733,
#  36005036800: 0.9393,
#  36005006000: 0.8863,
#  36005037600: 0.9148,
#  36005023301: 0.988,
#  36005004001: 0.8137,
#  36005006900: 0.9713,
#  36005003100: 0.885,
#  36005039000: 0.8127,
#  36005042800: 0.514,
#  36005038800: 0.9131,
#  36005005600: 0.9414,
#  36005014500: 0.9956,
#  36091060602: 0.2554,
#  36091062507: 0.0405,
#  36091062509: 0.1238,
#  36091060601: 0.4721,
#  36047017700: -999.0,
#  36047017800: 0.8644,
#  36047017900: 0.9236,
# ...
