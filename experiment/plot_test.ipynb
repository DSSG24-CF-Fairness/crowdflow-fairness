# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function y = -0.1 / x
def f(x):
    return -0.1 / x

# Generate x values for the two intervals
x1 = np.linspace(-1, -0.5, 100) + 1  # Shift the left side from -1 to -0.5 by 1 to the right
x2 = np.linspace(0.5, 1, 100)        # From 0.5 to 1

# Calculate y values for each interval with the required adjustments
y1 = f(x1 - 1) - (f(-0.5) - 0.5)  # Shifted left side interval to align vertically with (0.5, 1)
y2 = f(x2) + (0.5 - f(0.5))        # Right side interval with previous adjustment

# Plot the two curves with the adjusted y-values in the second interval
plt.plot(x1, y1, label='Shifted Curve for -1 < x < -0.5')
plt.plot(x2, y2, label='Adjusted Curve for 0.5 < x < 1')

# Highlight the transition point at (0.5, adjusted y-value)
plt.scatter([0.5], [0.5], color='red', zorder=5, label='Transition Point (0.5, 1)')

# Labeling the plot
plt.title('Concatenated Curve with Left Segment Shifted Right by 1')
plt.xlabel('x')
plt.ylabel('y')
plt.axvline(x=0.5, color='gray', linestyle='--', label='x = 0.5')  # Mark x=0.5
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the base function y = -0.1 / x
def f(x):
    return -0.1 / x

# Define an adjustment factor that makes the curve gradual near x = 0.5
def adjustment(x, center=0.5, width=0.5):
    return 1 + np.exp(-((x - center) ** 2) / (2 * width ** 2))

# Generate x values for the two intervals
x1 = np.linspace(-1, -0.5, 100) + 1  # Shift the left side from -1 to -0.5 by 1 to the right
x2 = np.linspace(0.5, 1, 100)        # From 0.5 to 1

# Calculate y values for each interval with the adjustment factor applied
y1 = f(x1 - 1) * adjustment(x1 - 1) - (f(-0.5) * adjustment(-0.5) - 0.5)  # Adjusted left interval
y2 = f(x2) * adjustment(x2) + (0.5 - f(0.5) * adjustment(0.5))            # Adjusted right interval

# Plot the two curves with the adjusted y-values in the second interval
plt.plot(x1, y1, label='Adjusted Curve for -1 < x < -0.5')
plt.plot(x2, y2, label='Adjusted Curve for 0.5 < x < 1')

# Highlight the transition point at (0.5, adjusted y-value)
plt.scatter([0.5], [0.5], color='red', zorder=5, label='Transition Point (0.5, 1)')

# Labeling the plot
plt.title('Concatenated Curve with Gradual Center and Steeper Ends')
plt.xlabel('x')
plt.ylabel('y')
plt.axvline(x=0.5, color='gray', linestyle='--', label='x = 0.5')  # Mark x=0.5
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100)  # From 0.01 to just left of 0.5
x_right = np.linspace(0.51, 1, 100)    # From just right of 0.5 to 1

# Calculate y values for each interval
y_left = f(x_left)
y_right = f(x_right)

# Plot the symmetric curve
plt.plot(x_left, y_left, label='Symmetric Curve for 0.01 < x < 0.5')
plt.plot(x_right, y_right, label='Symmetric Curve for 0.5 < x < 1')

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title('Centrosymmetric Curve Centered at x = 0.5')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-5, 5)  # Set a larger range for y-axis to maximize visibility
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100)  # From 0.01 to just left of 0.5
x_right = np.linspace(0.51, 1, 100)    # From just right of 0.5 to 1

# Calculate y values for each interval
y_left = np.abs(f(x_left))  # Flip the left side above the x-axis
y_right = f(x_right)        # Keep the right side as is

# Plot the symmetric curve
plt.plot(x_left, y_left, label='Flipped Symmetric Curve for 0.01 < x < 0.5')
plt.plot(x_right, y_right, label='Symmetric Curve for 0.5 < x < 1')

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title('Centrosymmetric Curve with Flipped Left Segment')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-5, 5)  # Set a larger range for y-axis to maximize visibility
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100) + 0.5  # Shift the left side (blue) by 0.5 to the right
x_right = np.linspace(0.51, 1, 100) - 0.5    # Shift the right side (orange) by 0.5 to the left

# Calculate y values for each interval
# Adjust the left (blue) and right (orange) curves to meet at y = 1
y_left = np.abs(f(x_left - 0.5)) - (np.abs(f(0.5 - 0.5)) - 1)  # Lower the blue curve to end at y = 1
y_right = f(x_right + 0.5) + (1 - f(0.5 + 0.5))                # Raise the orange curve to end at y = 1

# Plot the symmetric curve with adjustments applied
plt.plot(x_left, y_left, label='Adjusted Flipped Curve (Right) for 0.5 < x < 1')
plt.plot(x_right, y_right, label='Adjusted Curve (Left) for 0 < x < 0.5')

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title('Concatenated Centrosymmetric Curve Meeting at y=1')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-5, 5)  # Set a larger range for y-axis to maximize visibility
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100) + 0.5  # Shift the left side (blue) by 0.5 to the right
x_right = np.linspace(0.51, 1, 100) - 0.5    # Shift the right side (orange) by 0.5 to the left

# Calculate y values for each interval
# Adjust the left (blue) and right (orange) curves to meet at y = 1
y_left = np.abs(f(x_left - 0.5)) - (np.abs(f(0.5 - 0.5)) - 1)  # Lower the blue curve to end at y = 1
y_right = f(x_right + 0.5) + (1 - f(0.5 + 0.5))                # Raise the orange curve to end at y = 1

# Clip the y-values to restrict the range and avoid going to infinity at x=0 and x=1
y_left = np.clip(y_left, -5, 5)
y_right = np.clip(y_right, -5, 5)

# Plot the symmetric curve with adjustments applied
plt.plot(x_left, y_left, label='Adjusted Flipped Curve (Right) for 0.5 < x < 1')
plt.plot(x_right, y_right, label='Adjusted Curve (Left) for 0 < x < 0.5')

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title('Concatenated Centrosymmetric Curve Meeting at y=1 with Clipped Ends')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-2, 5)  # Set the range of y-axis to show the clipped values
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Set the range parameter to control the height of both curves
range = 4  # This will set each curve's "height" to half of this range

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100) + 0.5  # Shift the left side (blue) by 0.5 to the right
x_right = np.linspace(0.51, 1, 100) - 0.5    # Shift the right side (orange) by 0.5 to the left

# Calculate y values for each interval
# Adjust the left (blue) and right (orange) curves to meet at y = 1
y_left = (np.abs(f(x_left - 0.5)) - (np.abs(f(0.5 - 0.5)) - 1)) * (range / 4)
y_right = (f(x_right + 0.5) + (1 - f(0.5 + 0.5))) * (range / 4)

# Plot the symmetric curve with adjustments applied
plt.plot(x_left, y_left, label='Adjusted Flipped Curve (Right) for 0.5 < x < 1')
plt.plot(x_right, y_right, label='Adjusted Curve (Left) for 0 < x < 0.5')

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title(f'Concatenated Centrosymmetric Curve Meeting at y=1 with Range Control (range = {range})')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-range / 2, range / 2)  # Set y-axis to the specified range
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Set the range parameter to control the height of both curves
range = 2  # Example range; modify this to control the overall height

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100) + 0.5  # Shift the left side (blue) by 0.5 to the right
x_right = np.linspace(0.51, 1, 100) - 0.5    # Shift the right side (orange) by 0.5 to the left

# Calculate y values for each interval
# Scale and shift so that y=1 at the center, y=-1 at x=0, and y=3 at x=1
center_y = 1  # The y-value at the center (x=0.5)
scale_factor = range / 4  # Each curve should vary by half of the range above and below the center_y

y_left = (np.abs(f(x_left - 0.5)) - np.abs(f(0.5 - 0.5))) * scale_factor + center_y
y_right = (f(x_right + 0.5) - f(0.5 + 0.5)) * scale_factor + center_y

# Plot the symmetric curve with adjustments applied
plt.plot(x_left, y_left, label='Adjusted Flipped Curve (Right) for 0.5 < x < 1')
plt.plot(x_right, y_right, label='Adjusted Curve (Left) for 0 < x < 0.5')

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title(f'Concatenated Centrosymmetric Curve Meeting at y=1 with Range Control (range = {range})')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(center_y - range / 2, center_y + range / 2)  # Set y-axis to the specified range
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the modified symmetric function centered around x = 0.5
def f(x):
    return -0.1 / np.abs(x - 0.5)

# Set the range parameter to control the height of both curves
range = 2  # Example range; modify this to control the overall height
left_end_target = 1 - range / 2
right_end_target = 1 + range / 2

# Generate x values for both sides of the interval around 0.5
x_left = np.linspace(0.01, 0.49, 100) + 0.5  # Shift the left side (blue) by 0.5 to the right
x_right = np.linspace(0.51, 1, 100) - 0.5    # Shift the right side (orange) by 0.5 to the left

# Calculate y values for each interval
# Scale and shift so that y=1 at the center, y=-1 at x=0, and y=3 at x=1
center_y = 1  # The y-value at the center (x=0.5)
# scale_factor = range / 4  # Each curve should vary by half of the range above and below the center_y
scale_factor = (right_end_target - center_y) / (np.max(np.abs(f(x_left - 0.5))))


y_left = (np.abs(f(x_left - 0.5)) - np.abs(f(0.5 - 0.5))) * scale_factor + center_y
y_right = (f(x_right + 0.5) - f(0.5 + 0.5)) * scale_factor + center_y

steepness_factor = 10

# Apply additional steepness in the 0.2 < x < 0.8 range
y_left[x_left > 0.2] = (y_left[x_left > 0.2]) ** steepness_factor
y_right[x_right < 0.8] = (y_right[x_right < 0.8]) ** steepness_factor

# Plot the symmetric curve with adjustments applied
plt.plot(x_left, y_left)
plt.plot(x_right, y_right)

# Highlight the center of symmetry at x = 0.5
plt.axvline(x=0.5, color='gray', linestyle='--', label='Center of Symmetry x = 0.5')

# Labeling the plot
plt.title(f'Concatenated Centrosymmetric Curve Meeting at y=1 with Range Control (range = {range})')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(left_end_target, right_end_target)  # Set y-axis to the specified range
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the sigmoid
k = 5  # steepness of the sigmoid
x = np.linspace(0.001, 0.999, 500)  # x from 0 to 1

# Calculate the sigmoid function and scale it
y = 1 - (1 / (k * 1.1)) * np.log((1 - x) / x)

# Plot the result with a 90-degree rotation
plt.plot(x,y)  # Rotate by plotting y on the x-axis and x on the y-axis
plt.title("Rotated and Scaled Sigmoid Curve with Center at (1, 0.5)")
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 2.1)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the sigmoid
k = 5  # steepness of the sigmoid
x = np.linspace(0.001, 0.999, 500)  # x from 0 to 1

# Calculate the sigmoid function and scale it
y = 1 - (1 / (k * 1.1)) * np.log((1 - x) / x)

# Calculate the line y = x + 0.5
y_line = x + 0.5

# Plot the result with a 90-degree rotation
plt.plot(x, y, label='Scaled Sigmoid')
plt.plot(x, y_line, label='y = x + 0.5', linestyle='--')  # Adding the line with a dashed style

plt.title("Rotated and Scaled Sigmoid Curve with Center at (1, 0.5)")
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 2.1)
plt.grid()
plt.legend()  # Add a legend to distinguish the plots
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the sigmoid
k = 2  # steepness of the sigmoid
x = np.linspace(0.001, 0.999, 500)  # x from 0 to 1

# Calculate the sigmoid function and scale it
y = 1 - (1 / (k * 1.1)) * np.log((1 - x) / x)

# Calculate the line y = x + 0.5
y_line = x + 0.5

# Define the function y = I(x < 0.5) x/k + I(x > 0.5) kx
y_piecewise = np.where(x <= 0.5, x/k + (1-0.5/k), k*x + (1-0.5*k))

# Plot the results
plt.plot(x, y, label='Scaled Sigmoid')
plt.plot(x, y_line, label='y = x + 0.5', linestyle='--')
plt.plot(x, y_piecewise, label='Piecewise Linear', linestyle='-.')  # Adding the piecewise function

plt.title("Rotated and Scaled Sigmoid Curve with Additional Lines")
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 2.1)
plt.grid()
plt.legend()  # Add a legend to distinguish the plots
plt.show()

# %%
import numpy as np
k = 5
x_value = 1/9

y_value = 1 - (1 / (k * 1.1)) * np.log((1 - x_value) / x_value)
y_value
# Out:
# np.float64(0.6219197196945754)

# %%
k = 5
x_value = 4/9

y_value = 1 - (1 / (k * 1.5)) * np.log((1 - x_value) / x_value)
y_value
# Out:
# np.float64(0.9702475264914386)

# %%
k = 5
x_value = 5/9

y_value = 1 - (1 / (k * 1.5)) * np.log((1 - x_value) / x_value)
y_value
# Out:
# np.float64(1.0297524735085613)

# %%
k = 3
E = np.exp(k * 1.1)
x_value = 1 / (E + 1)

x_value
# Out:
# np.float64(0.03557118927263617)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the sigmoid
k = 20  # steepness of the sigmoid
x = np.linspace(0.001, 0.999, 500)  # x from 0 to 1

# Calculate the sigmoid function and scale it
y = 2 / (1 + np.exp(-k * (x - 0.5)))

# Plot the result with a 90-degree rotation
plt.figure(dpi=200)
plt.plot(x, y)
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 2.1)
plt.grid(True)  # Add background grid
plt.xlabel("Cumulative Percentile (CP)")  # Label x-axis
plt.ylabel("Bias Factor (BF)")  # Label y-axis

plt.savefig("../preprocessing/bias_adjustment_curve_k20.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import ConvexHull
import re
from IPython.display import display, HTML


def plot_fairness_vs_accuracy(location_name, accuracy_type, metric_type):
    results_G = pd.read_csv(f"../evaluation/{location_name}_G/{accuracy_type}/{metric_type}/{location_name}_G_log.csv")
    results_DG = pd.read_csv(f"../evaluation/{location_name}_DG/{accuracy_type}/{metric_type}/{location_name}_DG_log.csv")
    results_NLG = pd.read_csv(f"../evaluation/{location_name}_NLG/{accuracy_type}/{metric_type}/{location_name}_NLG_log.csv")

    data = {
        f"{location_name}_G": (results_G['accuracy'], results_G['fairness']),
        f"{location_name}_DG": (results_DG['accuracy'], results_DG['fairness']),
        f"{location_name}_NLG": (results_NLG['accuracy'], results_NLG['fairness'])
    }
    
    display(data)
    
    hull_colors = {f"{location_name}_G": "yellow", f"{location_name}_DG": "green", f"{location_name}_NLG": "orange"}
    point_colors = {"unbiased": "red", "ascending": "blue", "descending": "grey"}

    plt.figure(figsize=(10, 6))


    def get_label(filename):
        # Extract the index from the filename using a regular expression
        match = re.search(r'(\d+)', filename)
        if match:
            index = int(match.group(1))
            if index == 0:
                return "unbiased"
            elif 1 <= index <= 5 or 11 <= index <= 15:
                return "ascending"
            elif 6 <= index <= 10 or 16 <= index <= 20:
                return "descending"
        return "unknown"

    # Create handles for the legend (for both point and hull colors)
    legend_handles = {
        "hull_G": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='yellow', markersize=10, label=f"{location_name}_G"),
        "hull_DG": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label=f"{location_name}_DG"),
        "hull_NLG": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='orange', markersize=10, label=f"{location_name}_NLG"),
        "unbiased": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label="Unbiased"),
        "ascending": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label="Ascending"),
        "descending": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='grey', markersize=10, label="Descending")
    }

    # Plot points for each dataset
    for label, (accuracy, fairness) in data.items():
        # Loop through the dataset and apply get_label based on each filename
        for i, row in results_DG.iterrows():
            point_label = get_label(row['file_name'])  # Pass the filename to get_label
            plt.scatter(row['accuracy'], row['fairness'], color=point_colors[point_label], label=point_label if i == 0 else "", alpha=0.7)

        # Convex hull for each dataset
        points = np.column_stack((accuracy, fairness))
        hull = ConvexHull(points)
        for simplex in hull.simplices:
            plt.plot(points[simplex, 0], points[simplex, 1], color=hull_colors[label], linewidth=1)  # Hull edges in dataset color
        plt.fill(points[hull.vertices, 0], points[hull.vertices, 1], color=hull_colors[label], alpha=0.2)  # Hull fill

    hull_metrics = {}  # To store hull measurements for each dataset
    for label, (accuracy, fairness) in data.items():
        points = np.column_stack((accuracy, fairness))
        hull = ConvexHull(points)

        # Calculate height, width, and area of the hull
        min_x, max_x = points[hull.vertices, 0].min(), points[hull.vertices, 0].max()
        min_y, max_y = points[hull.vertices, 1].min(), points[hull.vertices, 1].max()

        width = max_x - min_x
        height = max_y - min_y
        area = hull.volume  # ConvexHull's `volume` property gives the 2D area for 2D points

        hull_metrics[label] = {
            "height": height,
            "width": width,
            "area": area
        }
    # Display hull metrics for each model
    for label, metrics in hull_metrics.items():
        print(f"Metrics for {label}:")
        print(f"  Height: {metrics['height']}")
        print(f"  Width: {metrics['width']}")
        print(f"  Area: {metrics['area']}\n")


    plt.xlabel(f'Performance (Mean {accuracy_type})')
    plt.ylabel(f'Fairness ({metric_type})')
    plt.title(f'Fairness vs. Accuracy for {location_name}')
    plt.ylim(plt.ylim())
    plt.xlim(plt.xlim())


    # Add the custom legend with padding
    plt.legend(handles=[
        legend_handles["hull_G"],
        legend_handles["hull_DG"],
        legend_handles["hull_NLG"],
        legend_handles["unbiased"],
        legend_handles["ascending"],
        legend_handles["descending"]
    ], title="Legend", loc='upper left', bbox_to_anchor=(1, 1), borderpad=1.5, handlelength=2)

    plt.grid(True)
    plt.show()

# %%
location_name = 'WA'
accuracy_type = 'CPC'
metric_type = 'kl_divergence'
plot_fairness_vs_accuracy(location_name, accuracy_type, metric_type)
# Out:
# {'WA_G': (0     0.277694
#   1     0.277694
#   2     0.277694
#   3     0.277694
#   4     0.277694
#   5     0.283636
#   6     0.283636
#   7     0.283636
#   8     0.283636
#   9     0.283636
#   10    0.297122
#   11    0.297122
#   12    0.297122
#   13    0.297122
#   14    0.297122
#   15    0.297130
#   16    0.297130
#   17    0.297130
#   18    0.297130
#   19    0.297130
#   20    0.301679
#   Name: accuracy, dtype: float64,
#   0     0.990284
#   1     0.990284
#   2     0.990284
#   3     0.990284
#   4     0.990284
#   5     0.989991
#   6     0.989991
#   7     0.989991
#   8     0.989991
#   9     0.989991
#   10    0.989369
#   11    0.989369
#   12    0.989369
#   13    0.989369
#   14    0.989369
#   15    0.989369
#   16    0.989369
#   17    0.989369
#   18    0.989369
#   19    0.989369
#   20    0.989142
#   Name: fairness, dtype: float64),
#  'WA_DG': (0     0.598040
#   1     0.557638
#   2     0.561465
#   3     0.561741
#   4     0.562210
# ...

# %%
location_name = 'WA'
accuracy_type = 'overestimation'
metric_type = 'kl_divergence'
plot_fairness_vs_accuracy(location_name, accuracy_type, metric_type)
# Out:
# Metrics for WA_G:
#   Height: 0.006875219026931223
#   Width: 0.8363022437428604
#   Area: 0.00029544142091610993
#
# Metrics for WA_DG:
#   Height: 0.03153123355738474
#   Width: 25.230232973000454
#   Area: 0.14961028878658592
#
# Metrics for WA_NLG:
#   Height: 0.04522500723375278
#   Width: 24.594001606015524
#   Area: 0.44295968999819707

# %%
location_name = 'WA'
accuracy_type = 'underestimation'
metric_type = 'kl_divergence'
plot_fairness_vs_accuracy(location_name, accuracy_type, metric_type)
# Out:
# Metrics for WA_G:
#   Height: 0.0005154127314319634
#   Width: 0.8454201486117405
#   Area: 8.407258262166738e-06
#
# Metrics for WA_DG:
#   Height: 0.06376413886941823
#   Width: 26.948394150434808
#   Area: 0.3570583518551345
#
# Metrics for WA_NLG:
#   Height: 0.04690358579592924
#   Width: 25.7911514315075
#   Area: 0.6885007275291305

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import ConvexHull
import re

def plot_fairness_vs_accuracy(location_name, accuracy_type, metric_type):
    # Load data
    results_G = pd.read_csv(f"../evaluation/{location_name}_G/{accuracy_type}/{metric_type}/{location_name}_G_log.csv")
    results_DG = pd.read_csv(f"../evaluation/{location_name}_DG/{accuracy_type}/{metric_type}/{location_name}_DG_log.csv")
    results_NLG = pd.read_csv(f"../evaluation/{location_name}_NLG/{accuracy_type}/{metric_type}/{location_name}_NLG_log.csv")

    data = {
        f"{location_name}_G": results_G,
        f"{location_name}_DG": results_DG,
        f"{location_name}_NLG": results_NLG
    }

    hull_colors = {f"{location_name}_G": "yellow", f"{location_name}_DG": "green", f"{location_name}_NLG": "orange"}
    point_colors = {"unbiased": "red", "ascending": "blue", "descending": "grey"}

    plt.figure(figsize=(12, 6))

    def get_label(filename):
        # Extract the index from the filename using a regular expression
        match = re.search(r'(\d+)', filename)
        if match:
            index = int(match.group(1))
            if index == 0:
                return "unbiased"
            elif 1 <= index <= 5 or 11 <= index <= 15:
                return "ascending"
            elif 6 <= index <= 10 or 16 <= index <= 20:
                return "descending"
        # Default to 'unbiased' if the pattern is not recognized
        return "unbiased"
    
    legend_handles = {
        "hull_G": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='yellow', markersize=10, label=f"{location_name}_G"),
        "hull_DG": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label=f"{location_name}_DG"),
        "hull_NLG": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='orange', markersize=10, label=f"{location_name}_NLG"),
        "unbiased": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=10, label="Unbiased"),
        "ascending": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label="Ascending"),
        "descending": plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='grey', markersize=10, label="Descending")
    }

    # Plot points for each dataset
    for label, df in data.items():
        scatter_groups = {color: [] for color in point_colors.keys()}  # Separate points by labels
        for _, row in df.iterrows():
            point_label = get_label(row['file_name'])  # Classify point
            if point_label not in scatter_groups:  # Safeguard against undefined labels
                point_label = "unbiased"  # Default to 'unbiased'
            scatter_groups[point_label].append((row['accuracy'], row['fairness']))

        # Plot points for each category
        for category, points in scatter_groups.items():
            if points:
                points = np.array(points)
                plt.scatter(points[:, 0], points[:, 1], color=point_colors[category], label=category, alpha=0.7)

        # Convex hull for each dataset
        points = np.column_stack((df['accuracy'], df['fairness']))
        hull = ConvexHull(points)
        for simplex in hull.simplices:
            plt.plot(points[simplex, 0], points[simplex, 1], color=hull_colors[label], linewidth=1)  # Hull edges in dataset color
        plt.fill(points[hull.vertices, 0], points[hull.vertices, 1], color=hull_colors[label], alpha=0.2)  # Hull fill

    plt.xlabel(f'Performance (Mean {accuracy_type})')
    plt.ylabel(f'Fairness ({metric_type})')
    plt.title(f'Fairness vs. Performance for {location_name}')

    # Add custom legend
    plt.legend(handles=[
        legend_handles["hull_G"],
        legend_handles["hull_DG"],
        legend_handles["hull_NLG"],
        legend_handles["unbiased"],
        legend_handles["ascending"],
        legend_handles["descending"]
    ], title="Legend", loc='upper left', bbox_to_anchor=(1, 1), borderpad=1.5, handlelength=2)

    plt.grid(True)
    plt.show()

# %%
location_name = 'WA'
accuracy_type = 'underestimation'
metric_type = 'kl_divergence'
plot_fairness_vs_accuracy(location_name, accuracy_type, metric_type)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np
from scipy.spatial import ConvexHull
import re






def plot_fairness_vs_accuracyy(location_name, accuracy_type, metric_type):
    results_DG = pd.read_csv(f"../evaluation/{location_name}_DG/{accuracy_type}/{metric_type}/{location_name}_DG_log.csv")

    data = {
        f"{location_name}_DG": (results_DG['accuracy'], results_DG['fairness']),
    }

    # display(data)

    hull_colors = {f"{location_name}_DG": "green"}
    point_colors = {"unbiased": "red", "ascending": "blue", "descending": "grey"}
    point_shapes = {"0": "o", "1": "s", "2": "^"}

    plt.figure(figsize=(10, 6))

    def get_label(filename):
        # Gravity log files
        if "gravity" in filename:
            if "1_ascending" in filename:
                return "ascending", "1"
            elif "1_descending" in filename:
                return "descending", "1"
            elif "2_ascending" in filename:
                return "ascending", "2"
            elif "2_descending" in filename:
                return "descending", "2"
            else:
                return "unbiased", "0"

        # DG/NLG log files
        elif "od2flow" in filename:
            # Extract the index from the filename using a regular expression
            numbers = re.findall(r'\d+', filename)
            # Convert numbers to integers (optional)
            numbers = [int(num) for num in numbers]

            index = None
            if len(numbers) == 2:
                index = numbers[1]

            if index == 0:
                return "unbiased", "0"
            elif 1 <= index <= 5:
                return "ascending", "1"
            elif 11 <= index <= 15:
                return "ascending", "2"
            elif 6 <= index <= 10:
                return "descending", "1"
            elif 16 <= index <= 20:
                return "descending", "2"
            else:
                return "unknown", "unknown"


    # Plot points for each dataset
    for label, (accuracy, fairness) in data.items():

        for i, row in results_DG.iterrows():
            point_order, point_method = get_label(row['file_name'])  # Pass the filename to get_label
            plt.scatter(row['accuracy'], row['fairness'], color=point_colors[point_order], marker=point_shapes[point_method], label=point_order if i == 0 else "", alpha=0.7)



        # Convex hull for each dataset
        points = np.column_stack((accuracy, fairness))
        hull = ConvexHull(points)
        for simplex in hull.simplices:
            plt.plot(points[simplex, 0], points[simplex, 1], color=hull_colors[label],
                     linewidth=1)  # Hull edges in dataset color
        plt.fill(points[hull.vertices, 0], points[hull.vertices, 1], color=hull_colors[label], alpha=0.2)  # Hull fill

    hull_metrics = {}  # To store hull measurements for each dataset
    for label, (accuracy, fairness) in data.items():
        points = np.column_stack((accuracy, fairness))
        hull = ConvexHull(points)

        # Calculate height, width, and area of the hull
        min_x, max_x = points[hull.vertices, 0].min(), points[hull.vertices, 0].max()
        min_y, max_y = points[hull.vertices, 1].min(), points[hull.vertices, 1].max()

        width = max_x - min_x
        height = max_y - min_y
        area = hull.volume  # ConvexHull's `volume` property gives the 2D area for 2D points

        hull_metrics[label] = {
            "height": height,
            "width": width,
            "area": area
        }
    # Display hull metrics for each model
    for label, metrics in hull_metrics.items():
        print(f"Metrics for {label}:")
        print(f"  Height: {metrics['height']}")
        print(f"  Width: {metrics['width']}")
        print(f"  Area: {metrics['area']}\n")

    plt.xlabel(f'Performance (Mean {accuracy_type})')
    plt.ylabel(f'Fairness ({metric_type})')
    plt.title(f'Fairness vs. Performance for {location_name}')
    plt.ylim(plt.ylim())
    plt.xlim(plt.xlim())



    # Define legend handles for hull colors
    hull_handles = [
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10, label=f"{location_name}_DG Hull")
    ]

    # Define legend handles for point combinations (color and shape)
    point_handles = [
        mlines.Line2D([], [], color='red', marker='o', linestyle='None', markersize=8, label="Unbiased"),
        mlines.Line2D([], [], color='blue', marker='s', linestyle='None', markersize=8, label="Ascending Method 1"),
        mlines.Line2D([], [], color='blue', marker='^', linestyle='None', markersize=8, label="Ascending Method 2"),
        mlines.Line2D([], [], color='grey', marker='s', linestyle='None', markersize=8, label="Descending Method 1"),
        mlines.Line2D([], [], color='grey', marker='^', linestyle='None', markersize=8, label="Descending Method 2")
    ]

    # Combine all legend handles
    legend_handles = hull_handles + point_handles

    # Add the legend to the plot
    plt.legend(handles=legend_handles, title="Legend", loc='upper left', bbox_to_anchor=(1, 1), borderpad=1.5, handlelength=2)



    plt.grid(True)

    plt.savefig(f"../evaluation/{location_name}_{accuracy_type}_{metric_type}_plot_test.png", bbox_inches='tight')

    plt.show()



location_name = 'NY'
accuracy_type = 'CPC'
metric_type = 'kl_divergence'
plot_fairness_vs_accuracyy(location_name, accuracy_type, metric_type)
# Out:
# Metrics for NY_DG:
#   Height: 0.026644140807543515
#   Width: 0.14981354611348963
#   Area: 0.0010283842587612202
